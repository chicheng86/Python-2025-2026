# %%
a=25
type(a)
# Out:
# int

# %%
a="7"
type(a)
# Out:
# str

# %%
b=a+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-ed15a91f7dcb> in <module>
# ----> 1 b=a+1
#
# TypeError: can only concatenate str (not "int") to str

# %%
# b=a+1
b=int(a)+1

# %%
print(b)
print('b is', b)
# Out:
# 8
# b is 8

# %%
type(b)
# Out:
# int

# %%
int(3.14)
# Out:
# 3

# %%
int(3.9)
# Out:
# 3

# %%
a=7
type(a)
# Out:
# int

# %%
str(a)
# Out:
# '7'

# %%
float(3)
# Out:
# 3.0

# %%
float('3.0')
# Out:
# 3.0

# %%
#my_age=38
user_age=input('How old are you?')
type(user_age)
# Out:
# How old are you?11
# str

# %%
my_age=38
user_age=input('How old are you?')
delta=my_age-int(user_age)
print('i am older than you kai is supa cool')
# Out:
# How old are you?11
# i am older than you kai is supa cool

# %%
my_age=38
user_age=input('How old are you?')
delta=my_age-int(user_age)
print('I am ', delta,'years older than you')
# Out:
# How old are you?11
# I am  27 years older than you
