# %%
type(3.14)
# Out:
# float

# %%
type(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-191ea9c3d109> in <module>
# ----> 1 type(x)
#
# NameError: name 'x' is not defined

# %%
x=5
type(x)
# Out:
# int

# %%
y='python'
type(y)
# Out:
# str

# %%
type(c)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-0acc8143872c> in <module>
# ----> 1 type(c)
#
# NameError: name 'c' is not defined

# %%
tip_percentage=(0.15)
type(tip_percentage)
# Out:
# float

# %%
tip_percentage=('0.15')
type(tip_percentage)
# Out:
# str

# %%
float(tip_percentage)
# Out:
# 0.15

# %%
float(3)
# Out:
# 3.0

# %%
int(3.0)
# Out:
# 3

# %%
str(3.0)
# Out:
# '3.0'

# %%
my_age=38
user_age=input('How old are you?')
# delta=my_age-user_age  --> This is wrong, and will get error. Try it !
delta=my_age-int(user_age)
print('I am ', delta,'years older than you')
# Out:
# How old are you?12
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-33ae75884192> in <module>
#       1 my_age=38
#       2 user_age=input('How old are you?')
# ----> 3 delta=my_age-user_age
#       4 #delta=my_age-int(user_age)
#       5 print('I am ', delta,'years older than you')
#
# TypeError: unsupported operand type(s) for -: 'int' and 'str'

# %%
dinner_cost=100
tip_percentage=0.18
tip=dinner_cost*tip_percentage
print(tip)
# Out:
# 18.0

# %%
dinner_cost=input('dinner amt')
tip_percentage=input('tip amt')
tip=float(dinner_cost)*float(tip_percentage)/100
print(tip)
# Out:
# dinner amt100
# tip amt18
# 18.0

# %%
def tip_calculator():
    dinner_cost=input('dinner amt')
    tip_percentage=input('tip amt')
    tip=float(dinner_cost)*float(tip_percentage)/100
    print(tip)

# %% [markdown]
# wrtie a piece of code to calculate tip.
# the input you need can get from user (chatbot)
# dinner cost. tip percentage.

# %%
tip_calculator()
# Out:
# dinner amt100
# tip amt18
# 18.0
