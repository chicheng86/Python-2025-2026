# %%
type('3.14')
# Out:
# str

# %%
x='3,14'
type(x)
# Out:
# str

# %%
y=3.14
type(y)
# Out:
# float

# %%
x=3.14
x=3
type(x)
# Out:
# int

# %%
age=input('how old are you? ')
type(age)
# Out:
# how old are you? 10
# str

# %%
def tip_calculator():  #header to define a fucntion
    dinner_cost=100
    tip_percentage=0.18
    tips=dinner_cost*tip_percentage
    print(tips)

# %%
tip_calculator()
# Out:
# 18.0

# %%
def tax_calculator():
    dinner_cost=100
    tax_percentage=0.0838
    tax=dinner_cost*tax_percentage
    print(tax)
tax_calculator()
# Out:
# 8.38

# %%
def tax_calculator_v1(dinner_cost):
    tax_percentage=0.0838
    tax=dinner_cost*tax_percentage
    print(tax)

# %%
dinner_cost=100
tax_calculator_v1(dinner_cost)
# Out:
# 8.38

# %%
dinner_cost=20
tax_calculator_v1(dinner_cost)
# Out:
# 1.676

# %%
tax_calculator_v1(100)
# Out:
# 8.38

# %%
tax_calculator_v1(12345674337436726829478543297474758456428462983762983467948652498564352743659842654398526432894365284375698469865432985643587264985497659743982574398)
# Out:
# 1.0345675094771977e+147
